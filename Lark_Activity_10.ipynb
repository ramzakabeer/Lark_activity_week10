# %%
#Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the data into python

# %%
data=pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\ICT\Datas\Lark Activity/week10.csv')

# %%
data.head()
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 4   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       18.436525       100.341674   4.628771
# 1       11.558279        31.997993   4.075075
# 2        8.399735        54.917862   2.559708
# 3       13.789695        84.603556   2.672989
# 4       12.363817        62.798309   4.401425

# %%
data.shape
# Out:
# (2011, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 141.5 KB

# %% [markdown]
# # Check for null values

# %%
data.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# # Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

# %%
data.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# 'Hardness','Sulfate' and 'Organic Carbon' are normally distributed.

# %%
data.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity'],
#       dtype='object')

# %%
print(data['Hardness'].unique())
print(data['Sulfate'].unique())
print(data['Organic_carbon'].unique())
# Out:
# [214.3733941  181.1015092  188.3133238  ...  94.81254522 186.6590397
#  193.6817355 ]
# [356.8861356 310.1357375 326.6783629 ... 258.9306004 345.7002573
#  359.9485744]
# [18.4365245  11.55827944  8.39973464 ... 16.17275544 12.06761957
#  13.89441852]

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441375     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587065     8.109726   359.330555
# max      14.000000   317.338124  56488.672410    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity
# count   2011.000000     2011.000000      2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729
# std       80.712572        3.324959        16.077109     0.780346
# ...

# %% [markdown]
# 'Hardness','Sulfate' and 'Organic Carbon' contains continuous numeric values.

# %%
plt.boxplot(data[["Hardness","Sulfate","Organic_carbon"]])
plt.show()

# %% [markdown]
# Outliers are found on 'Hardness' and 'Sulfate'.

# %% [markdown]
# # Carry out correlation analysis on the dataset and find the correlation factor between

# %% [markdown]
# # a. ph and Chloramines b. ph and Conductivity

# %% [markdown]
# # What do we infer from this correlation value?

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=-.2,vmax=.8,annot=True,linewidth=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ph and Chloramines has a low negative correlation of -0.025 whereas the correlation between ph and Conductivity is 0.014,which is a low positive correlation.Therefore, we can conclude that there is weak linear relationship between variables.
